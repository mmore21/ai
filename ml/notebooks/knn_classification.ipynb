# %% [markdown]
# # K-Nearest Neighbors

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math
from collections import Counter

# %%
# Read example data
data = pd.read_csv("datasets/college_admission.txt", header=None)

# %%
# Convert and split data into numpy arrays
X = np.asarray(data.iloc[:,0:2])
y = np.asarray(data.iloc[:,2])

# %%
from algorithms.k_nearest_neighbors import *

# %%
plot_data(X, y)

# %%
test_scores = [75, 80]

prediction = knn(X, y, test_scores, 3)

# %%
print("K-Nearest Neighbors (Distance, Index): ", prediction)

if (prediction[0]):
    print("Model prediction: accepted admission.")
else:
    print("Model prediction: declined admission.")
# Out:
# K-Nearest Neighbors (Distance, Index):  ([(3.557263705630598, 59), (4.87162314539783, 93), (5.773506639157046, 60)], 1)
# Model prediction: accepted admission.
